# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/accidents.txt', sep=',', error_bad_lines=False, index_col=False, encoding= 'unicode_escape',dtype='unicode')

# %%
df.head()
# Out:
#     VKL_NUMMER   REGNUMMER PVOPGEM DATUM_VKL DAG_CODE MND_NUMMER JAAR_VKL  \
# 0  20190011333  2019026344     NaN       NaN      NaN        NaN     2019
# 1  20190011334  2019025165     NaN       NaN      NaN        NaN     2019
# 2  20190011335  2019026461     NaN       NaN      NaN        NaN     2019
# 3  20190011336  2019025726     NaN       NaN      NaN        NaN     2019
# 4  20190011337  2019024583     NaN       NaN      NaN        NaN     2019
#
#   TIJDSTIP  UUR DDL_ID  ...   PVE_NAAM KDD_NAAM  \
# 0      NaN  NaN    NaN  ...  Friesland      NaN
# 1      NaN  NaN    NaN  ...    Drenthe      NaN
# 2      NaN  NaN    NaN  ...    Drenthe      NaN
# 3      NaN  NaN    NaN  ...    Drenthe      NaN
# 4      NaN  NaN    NaN  ...  Groningen      NaN
#
#                                    PLT_NAAM DIENSTCODE DIENSTNAAM DISTRCODE  \
# 0  Regionale Eenheid Noord-Nederland               NaN        NaN       NaN
# 1  Regionale Eenheid Noord-Nederland               NaN        NaN       NaN
# 2  Regionale Eenheid Noord-Nederland                NN         NN       100
# 3  Regionale Eenheid Noord-Nederland               NaN        NaN       NaN
# 4                                       NaN         NN         NN       100
#
#           DISTRNAAM DAGTYPE IND_ALC WEEKNR
# 0               NaN     NaN     NaN    NaN
# 1               NaN     NaN     NaN    NaN
# 2  NN District Oost     NaN     NaN    NaN
# 3               NaN     NaN     NaN    NaN
# 4  NN District Oost     NaN     NaN    NaN
#
# [5 rows x 66 columns]

# %%
df.columns
# Out:
# Index(['VKL_NUMMER', 'REGNUMMER', 'PVOPGEM', 'DATUM_VKL', 'DAG_CODE',
#        'MND_NUMMER', 'JAAR_VKL', 'TIJDSTIP', 'UUR', 'DDL_ID', 'AP3_CODE',
#        'AP4_CODE', 'AP5_CODE', 'ANTL_SLA', 'ANTL_DOD', 'ANTL_GZH', 'ANTL_SEH',
#        'ANTL_GOV', 'ANTL_PTJ', 'ANTL_TDT', 'MNE_CODE', 'AOL_ID', 'NIVEAUKOP',
#        'WSE_ID', 'WSE_AN', 'BEBKOM', 'MAXSNELHD', 'WVL_ID', 'WVG_ID', 'WVG_AN',
#        'WDK_ID', 'WDK_AN', 'LGD_ID', 'ZAD_ID', 'WGD_CODE_1', 'WGD_CODE_2',
#        'BZD_ID_VM1', 'BZD_ID_VM2', 'BZD_ID_VM3', 'BZD_VM_AN', 'BZD_ID_IF1',
#        'BZD_ID_IF2', 'BZD_ID_IF3', 'BZD_IF_AN', 'BZD_ID_TA1', 'BZD_ID_TA2',
#        'BZD_ID_TA3', 'BZD_TA_AN', 'JTE_ID', 'WVK_ID', 'HECTOMETER', 'FK_VELD5',
#        'HUISNUMMER', 'GME_ID', 'GME_NAAM', 'PVE_CODE', 'PVE_NAAM', 'KDD_NAAM',
#        'PLT_NAAM', 'DIENSTCODE', 'DIENSTNAAM', 'DISTRCODE', 'DISTRNAAM',
#        'DAGTYPE', 'IND_ALC', 'WEEKNR'],
#       dtype='object')

# %%
# DROPPING UNNCESSARY COLUMNS FOR OUR ANALYSIS

drop_columns = ['REGNUMMER','PVOPGEM', 'DATUM_VKL', 'DAG_CODE',
       'MND_NUMMER','JAAR_VKL', 'TIJDSTIP', 'UUR', 'DDL_ID',
       'AP4_CODE', 'AP5_CODE', 'ANTL_SLA', 'ANTL_DOD', 'ANTL_GZH', 'ANTL_SEH',
       'ANTL_GOV', 'ANTL_TDT', 'MNE_CODE','WSE_AN', 'BEBKOM', 'WVG_ID', 'WVG_AN','WDK_AN',
       'ZAD_ID','WGD_CODE_2','BZD_ID_VM1', 'BZD_ID_VM2', 'BZD_ID_VM3', 'BZD_VM_AN', 'BZD_ID_IF1',
       'BZD_ID_IF2', 'BZD_ID_IF3', 'BZD_IF_AN', 'BZD_ID_TA1', 'BZD_ID_TA2',
       'BZD_ID_TA3', 'BZD_TA_AN', 'JTE_ID', 'WVK_ID', 'HECTOMETER', 'FK_VELD5',
       'HUISNUMMER','PLT_NAAM', 'DIENSTCODE', 'DIENSTNAAM', 
       'DAGTYPE', 'WEEKNR']

df = df.drop(drop_columns,axis=1)

# %%
# KEEP THIS ONE TO SEE ORIGINAL COLUMN NAMES FOR DOCUMENTATION BEFORE RENAMING & ALSO FOR REFERENCES

df.columns

#VKL_NUMMER = Accident_ID
#AP3_CODE = Accident_Outcome                 ### Reference List: Aflopen3 i
#ANTL_PTJ = Number_Involvers
#AOL_ID = Type_Accident                      ### Reference List: AardOngevallen (Earth Accidents)

#NIVEAUKOP = Road_Level                      ### E=Accident exactly linked to BN, K=K = Accident linked at intersection level,S = Accident linked at street level,G = Accident linked to municipal level
#WSE_ID = Road_Situation                     ### Reference List: wegsituaties (Road Situations)
#WVL_ID = Road_Lightning                     ### Reference List: Wegverlichtingen (Road Lighting)
#WDK_ID = Road_Surface                       ### Reference list: Wegdekken (Road surfaces)
#WGD_CODE_1 = Road_Situation_2               ### D = Droog, R = Regen, M = Mist, S = Sneeuw/Hagel, H = Harde windstoten, O = Onbekend



#IND_ALC = Alcohol_Indication                ### J : Yes , N: No
#MAXSNELHD = Allowed_Max_Speed 
#LGD_ID = Lightning_Conditions_Accident      ### Reference List: Lichtgesteldheden (Lighting Conditions)
# Out:
# Index(['VKL_NUMMER', 'AP3_CODE', 'ANTL_PTJ', 'AOL_ID', 'NIVEAUKOP', 'WSE_ID',
#        'MAXSNELHD', 'WVL_ID', 'WDK_ID', 'LGD_ID', 'WGD_CODE_1', 'GME_ID',
#        'GME_NAAM', 'PVE_CODE', 'PVE_NAAM', 'KDD_NAAM', 'DISTRCODE',
#        'DISTRNAAM', 'IND_ALC'],
#       dtype='object')

# %%
#RENAMING WHAT'S LEFT

df.columns=['Accident_ID', 'Accident_Outcome', 'Number_Involvers', 'Type_Accident',
       'Road_Level', 'Road_Situation', 'Allowed_Max_Speed', 'Road_Lightning', 'Road_Surface',
       'Lightning_Conditions_Accident', 'Road_Situation_2','City_ID','City_Name','Province_Code', 'Province_Name', 'Regions',
        'District_Code', 'District_Name', 'Alcohol_Indication']

# %%
### CONVERTING CATEGORIZED DATA INTO ITS' REFERENCES\n",

df["Accident_Outcome"].replace({"UMS":"Only_material_dmg","LET":"Injured","DOD":"Deadly"}, inplace=True)

df["Type_Accident"].replace({"0": "Unkown", "1": "Pedestrian","2":"Parked_Vehicle","3":"Animal","4":"Solid_Object",
                   "5":"Loose_Object","6":"Frontal","7":"Flank","8":"Head/tail","9":"One-sided"}, inplace=True)
   
df["Road_Level"].replace({"E": "Accident exactly linked to BN", "K": "Accident linked at intersection level",
                        "S":"Accident linked at street level","G":"Accident linked to municipal level"}, inplace=True)

df["Road_Situation"].replace({"1": "Straight_Road", "2":"Bend","3":"Roundabout","4":"Crossroads_3_branches",
                              "5":"Crossroad_4_branches"}, inplace=True)

df["Road_Surface"].replace({"1": "Dry", "2": "Wet","3":"Snow"}, inplace=True)

df["Road_Situation_2"].replace({"D":"Dry","R":"Rain","M":"Mist","S":"Snow","H":"Strong_Wind","O":"Unkown"}, inplace=True)

df["Lightning_Conditions_Accident"].replace({"1": "Daylight", "2": "Darkness","3":"Dusk"}, inplace=True)

df.head()
# Out:
#    Accident_ID   Accident_Outcome Number_Involvers Type_Accident  \
# 0  20190011333  Only_material_dmg                2        Unkown
# 1  20190011334            Injured                2  Solid_Object
# 2  20190011335  Only_material_dmg                1        Unkown
# 3  20190011336            Injured                3     Head/tail
# 4  20190011337  Only_material_dmg                2     Head/tail
#
#                            Road_Level Road_Situation Allowed_Max_Speed  \
# 0       Accident exactly linked to BN  Straight_Road                60
# 1     Accident linked at street level  Straight_Road                80
# 2  Accident linked to municipal level  Straight_Road                30
# 3       Accident exactly linked to BN           Bend                80
# 4       Accident exactly linked to BN  Straight_Road               130
#
#   Road_Lightning Road_Surface Lightning_Conditions_Accident Road_Situation_2  \
# 0              1         Snow                          Dusk              Dry
# 1              3         Snow                      Daylight              Dry
# 2              1          Dry                      Darkness             Snow
# 3              3         Snow                      Darkness              Dry
# 4              1          Wet                          Dusk             Rain
#
#   City_ID         City_Name Province_Code Province_Name Regions District_Code  \
# 0      85  Ooststellingwerf            FR     Friesland     NaN           NaN
# 1    1681     Borger-Odoorn            DR       Drenthe     NaN           NaN
# 2     114             Emmen            DR       Drenthe     NaN           100
# 3    1701        Westerveld            DR       Drenthe     NaN           NaN
# 4    1969    Westerkwartier            GR     Groningen     NaN           100
#
#       District_Name Alcohol_Indication
# 0               NaN                NaN
# 1               NaN                NaN
# 2  NN District Oost                NaN
# 3               NaN                NaN
# 4  NN District Oost                NaN

# %%
df.isnull().sum()
# Out:
# Accident_ID                           0
# Accident_Outcome                      0
# Number_Involvers                      0
# Type_Accident                         0
# Road_Level                            0
# Road_Situation                    51768
# Allowed_Max_Speed                 31410
# Road_Lightning                    51760
# Road_Surface                      50929
# Lightning_Conditions_Accident         3
# Road_Situation_2                  52080
# City_ID                               0
# City_Name                             0
# Province_Code                         0
# Province_Name                         0
# Regions                           20271
# District_Code                     90081
# District_Name                     90081
# Alcohol_Indication               132120
# dtype: int64

# %%
# ONE HOT DECODING FOR EACH COLUMN TO CHECK CORRELATIONS

df_onehot = df.copy()

# Accident Outcome Onehot Encoding
df_onehot_type_accident = pd.get_dummies(df_onehot, columns=['Accident_Outcome'], prefix = ['Accident_Outcome'])
df_onehot_type_accident

# Type of Accident Onehot Encoding
df_onehot_road_level = pd.get_dummies(df_onehot, columns=['Road_Level'], prefix = ['Road_Level'])
df_onehot_road_level

# Road Situation Onehot Encoding
df_onehot_road_situation = pd.get_dummies(df_onehot, columns=['Road_Situation'], prefix = ['Road_Situation'])
df_onehot_road_situation

# Road Surface Onethot Encoding
df_onehot_road_surface = pd.get_dummies(df_onehot, columns=['Road_Surface'], prefix = ['Road_Surface'])
df_onehot_road_surface

# Lightning Conditions Encoding
df_onehot_lightning_conditions_accident = pd.get_dummies(df_onehot, columns=['Lightning_Conditions_Accident'], prefix = ['Lightning_Conditions_Accident'])
df_onehot_lightning_conditions_accident

# Road Situatuon 2 Onehot Encoding
df_onehot_road_situation_2 = pd.get_dummies(df_onehot, columns=['Road_Situation_2'], prefix = ['Road_Situation_2'])
df_onehot_road_situation_2

# %%
# TO SEE DISTINCT VALUES IN EACH COLUMN - for specific ones - TO UNDERSTAND DATABASE :)

df.columns=['Accident_ID', 'Accident_Outcome', 'Number_Involvers', 'Type_Accident',
       'Road_Level', 'Road_Situation', 'Allowed_Max_Speed', 'Road_Lightning', 'Road_Surface',
       'Lightning_Conditions_Accident', 'Road_Situation_2','City_ID','City_Name','Province_Code',
        'Province_Name', 'Regions','District_Code', 'District_Name', 'Alcohol_Indication']

string_columns = ['Accident_Outcome','Type_Accident','Road_Level','Road_Situation','Road_Lightning',
                  'Road_Surface','Lightning_Conditions_Accident','Road_Situation_2','City_Name','Province_Code',
                  'Province_Name','Regions','District_Code', 'District_Name', 'Alcohol_Indication']

distinct_values_in_each_cell = []
for column in df[string_columns]:
    distinct_values_in_each_cell.append(set(df[column].values))
    print(column, "has", distinct_values_in_each_cell[-1], "\n")
# Out:
# Accident_Outcome has {'Injured', 'Deadly', 'Only_material_dmg'}
#
# Type_Accident has {'Parked_Vehicle', 'Unkown', 'Head/tail', 'One-sided', 'Animal', 'Flank', 'Frontal', 'Solid_Object', 'Pedestrian', 'Loose_Object'}
#
# Road_Level has {'Accident linked at intersection level', 'Accident exactly linked to BN', 'Accident linked at street level', 'Accident linked to municipal level'}
#
# Road_Situation has {nan, 'Bend', 'Straight_Road', 'Crossroads_3_branches', 'Roundabout', 'Crossroad_4_branches'}
#
# Road_Lightning has {nan, '3', '1', '2'}
#
# Road_Surface has {'Dry', nan, 'Snow', 'Wet'}
#
# Lightning_Conditions_Accident has {nan, 'Daylight', 'Dusk', 'Darkness'}
#
# Road_Situation_2 has {'Dry', nan, 'Mist', 'Rain', 'Snow', 'Strong_Wind'}
#
# City_Name has {'Hattem', 'Zoeterwoude', 'Buren', 'Hengelo', 'Westerkwartier', 'Losser', 'Opsterland', 'Nuenen  Gerwen en Nederwetten', 'Hardenberg', 'Doesburg', 'Halderberge', 'Bergeijk', 'Overbetuwe', 'Cuijk', 'Aalsmeer', 'Midden-Delfland', 'Westervoort', 'Noardeast-Fryslân', 'Oss', 'Bunnik', 'Nieuwegein', 'Lelystad', 'Steenwijkerland', 'Noordoostpolder', 'Voerendaal', 'Hoorn', 'Oude IJsselstreek', 'Goirle', 'Waalwijk', 'Stadskanaal', 'Ooststellingwerf', 'Lingewaard', 'Vlieland', 'Hulst', 'Schiermonnikoog', 'Capelle aan den IJssel', 'Wormerland', 'Uitgeest', 'Brummen', 'Barneveld', 'Edam-Volendam', 'Bronckhorst', 'Veendam', 'Hilversum', 'Valkenburg aan de Geul', 'Bloemendaal', 'Tilburg', 'Middelburg', 'Amsterdam', 'Oosterhout', 'Weesp', 'Rotterdam', 'Geertruidenberg', 'Westvoorne', 'Woerden', 'Twenterand', 'Waddinxveen', 'Haarlemmermeer', "'s-Hertogenbosch", 'Krimpenerwaard', 'Helmond', 'Kerkrade', 'Heemskerk', 'Enschede', 'Roerdalen', 'Albrandswaard', 'Elburg', 'Leusden', 'Hardinxveld-Giessendam', 'Drimmelen', 'Hendrik-Ido-Ambacht', 'Lansingerland', 'De Ronde Venen', 'Wierden', 'Dalfsen', 'Waadhoeke', 'Westerwolde', 'Súdwest-Fryslân', 'Zundert', 'Borsele', 'Oldebroek', 'Gouda', 'West Betuwe', 'Bunschoten', 'Hellevoetsluis', 'De Bilt', 'Pekela', 'Assen', 'Ouder-Amstel', 'Stichtse Vecht', 'Enkhuizen', 'Maastricht', 'Deurne', 'Maasgouw', 'Noord-Beveland', 'Loppersum', 'Kaag en Braassem', 'Hollands Kroon', 'Oegstgeest', 'Tynaarlo', 'Etten-Leur', 'Oost Gelre', 'Woudenberg', 'Maasdriel', 'Den Helder', 'Zwijndrecht', 'Gemert-Bakel', 'Renkum', 'Rucphen', 'Leeuwarden', 'Wijchen', 'Eijsden-Margraten', 'Venlo', 'West Maas en Waal', 'Beek', 'Moerdijk', 'Eindhoven', 'Amstelveen', 'Veldhoven', 'Nijkerk', 'Baarle-Nassau', 'Zaltbommel', 'Smallingerland', 'Heerhugowaard', 'Meppel', 'Horst aan de Maas', 'Sint Anthonis', 'Wijdemeren', 'Hillegom', 'Uden', 'Leiden', 'Schiedam', 'Krimpen aan den IJssel', 'Zuidplas', 'Eemnes', 'Echt-Susteren', 'Sittard-Geleen', 'Rhenen', 'Beemster', 'Houten', 'Veere', 'Reimerswaal', 'Wassenaar', 'Voorst', 'Zevenaar', 'Hoogeveen', 'Veenendaal', 'Ameland', 'Boxmeer', 'Waalre', 'Nijmegen', 'Westland', 'Laarbeek', 'Utrechtse Heuvelrug', 'Ridderkerk', 'Scherpenzeel', 'Texel', 'Leudal', 'Barendrecht', 'Zoetermeer', 'Boekel', 'Gilze en Rijen', 'Groningen', 'Mook en Middelaar', 'Boxtel', 'Haaren', 'Terschelling', 'Doetinchem', 'Maassluis', 'Nissewaard', 'Aa en Hunze', 'Schagen', 'Bladel', 'Heerenveen', 'Meierijstad', 'Lochem', 'Diemen', 'Heerde', 'Molenlanden', 'Neder-Betuwe', 'Ede', 'Bergen (NH.)', 'Midden-Drenthe', 'Delft', 'Putten', 'Hoeksche Waard', "'s-Gravenhage", 'Alblasserdam', 'Blaricum', 'Culemborg', 'Sluis', 'Tiel', 'Heiloo', 'Langedijk', 'Drechterland', 'Venray', 'Brunssum', 'Oostzaan', 'Vijfheerenlanden', 'Rheden', 'Raalte', 'De Fryske Marren', 'Gooise Meren', 'Vught', 'Stede Broec', 'Dinkelland', 'Rijswijk', 'Druten', 'Roermond', 'Berg en Dal', 'Oisterwijk', 'Gennep', 'Apeldoorn', 'Heumen', 'Oldenzaal', 'Dordrecht', 'Medemblik', 'Koggenland', 'Waterland', 'Tholen', 'Utrecht', 'Beuningen', 'Almere', 'Lopik', 'Beesel', 'Arnhem', 'Altena', 'Heusden', 'Delfzijl', 'Teylingen', 'Castricum', 'Stein', 'Reusel-De Mierden', 'Velsen', 'Staphorst', 'Steenbergen', 'Bergen (L.)', 'Terneuzen', 'Woensdrecht', 'Lisse', 'Vlissingen', 'Beverwijk', 'Tubbergen', 'Renswoude', 'Aalten', 'Weststellingwerf', 'Leiderdorp', 'Zeist', 'Alphen-Chaam', 'Baarn', 'Goes', 'Vaals', 'Katwijk', 'Midden-Groningen', 'Cranendonck', 'Hilvarenbeek', 'Coevorden', 'Oudewater', 'Berkelland', 'Appingedam', 'Ommen', 'Deventer', 'Landgraaf', 'Zaanstad', 'Valkenswaard', 'Ermelo', 'Amersfoort', 'Harderwijk', 'Noordenveld', 'Papendrecht', 'Voorschoten', 'Meerssen', 'Brielle', 'Gulpen-Wittem', 'Dantumadiel', 'Het Hogeland', 'Dongen', 'Noordwijk', 'Breda', 'Sliedrecht', 'Epe', 'Huizen', 'De Wolden', 'Zwartewaterland', 'Landerd', 'Vlaardingen', 'Hellendoorn', 'Roosendaal', 'Zwolle', 'Uithoorn', 'Dronten', 'Haaksbergen', 'Urk', 'Olst-Wijhe', 'Schouwen-Duiveland' ...
#
# Province_Code has {'NB', 'FL', 'GL', 'DR', 'OV', 'UT', 'ZH', 'ZL', 'GR', 'FR', 'NH', 'LB'}
#
# Province_Name has {'Zuid-Holland', 'Overijssel', 'Limburg', 'Zeeland', 'Flevoland', 'Utrecht', 'Noord-Holland', 'Gelderland', 'Noord-Brabant', 'Drenthe', 'Groningen', 'Friesland'}
#
# Regions has {nan, 'KNOOPPUNT ARNHEM-NIJMEGEN               ', 'REGIO UTRECHT-OV                        ', 'REGIO GELDERLAND-OV                     ', 'REGIO TWENTE                            ', 'REGIO OVERIJSSEL-OV                     ', 'STADSGEWEST HAAGLANDEN                  ', 'SAMENWERKINGSVERBAND REGIO EINDHOVEN    ', 'REGIO NOORD HOLLAND-OV                  ', 'BESTUUR REGIO UTRECHT                   ', 'REGIO NOORD BRABANT-OV                  ', 'STADSREGIO ROTTERDAM                    ', 'REGIO LIMBURG                           ', 'REGIO ZUID HOLLAND-OV                   ', 'REGIONAAL ORGAAN AMSTERDAM              '}
#
# District_Code has {nan, '199', '193', '100', '113', '112', '195', '144', '137', '187', '645', '159', '161', '136', '194', '160', '143', '186'}
#
# District_Name has {nan, 'ON District Oost', 'MN District Zuid', 'ZN District Zuid-Oost', 'ZD District Zuid', 'ON District Zuid', 'ZD District Noord', 'WNN District Noord', 'ZN District West', 'NN District Oost', 'MN District Noord', 'ON District Noord', 'WNZ District Noord', 'ZN District Midden', 'Oost-Nederland District Zuid', 'WNN District Zuid', 'WNZ District Zuid', 'NN District West'}
#
# Alcohol_Indication has {nan, 'J'}

# %% [markdown]
# ## Questions
#
# 1) Accident outcome - road situation_2 (If wet, death ratio higher?) -check when it's wet, when it's dry
# 2) Group by city and sum accident ID's to have an idea about number of accidents in each city
# 3) Accident outcome - road lighthning (If day time, accidents more predictable, less death ratio maybe)
# 4) Accident outcome - alcohol indication (if yes more deaths)
# 5) Type of accident happened most in Amsterdam (Refer AardOngevallen.txt and merge the dataframe for demonstration??)
