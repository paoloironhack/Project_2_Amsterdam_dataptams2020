# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/accidents.csv', sep=',', error_bad_lines=False, index_col=False, encoding= 'unicode_escape',dtype='unicode')

# %%
df
# Out:
#          VKL_NUMMER   REGNUMMER PVOPGEM DATUM_VKL DAG_CODE MND_NUMMER  \
# 0       20190011333  2019026344     NaN       NaN      NaN        NaN
# 1       20190011334  2019025165     NaN       NaN      NaN        NaN
# 2       20190011335  2019026461     NaN       NaN      NaN        NaN
# 3       20190011336  2019025726     NaN       NaN      NaN        NaN
# 4       20190011337  2019024583     NaN       NaN      NaN        NaN
# ...             ...         ...     ...       ...      ...        ...
# 134612  20190078930  2019157605     NaN       NaN      NaN        NaN
# 134613  20190078931  2019074965     NaN       NaN      NaN        NaN
# 134614  20190078932  2019100231     NaN       NaN      NaN        NaN
# 134615  20190078933  2019024608     NaN       NaN      NaN        NaN
# 134616  20190078934  2019025092     NaN       NaN      NaN        NaN
#
#        JAAR_VKL TIJDSTIP  UUR DDL_ID  ...   PVE_NAAM  \
# 0          2019      NaN  NaN    NaN  ...  Friesland
# 1          2019      NaN  NaN    NaN  ...    Drenthe
# 2          2019      NaN  NaN    NaN  ...    Drenthe
# 3          2019      NaN  NaN    NaN  ...    Drenthe
# 4          2019      NaN  NaN    NaN  ...  Groningen
# ...         ...      ...  ...    ...  ...        ...
# 134612     2019      NaN  NaN    NaN  ...    Limburg
# 134613     2019      NaN  NaN    NaN  ...    Limburg
# 134614     2019      NaN  NaN    NaN  ...    Limburg
# 134615     2019      NaN  NaN    NaN  ...    Limburg
# 134616     2019      NaN  NaN    NaN  ...    Limburg
#
#                                         KDD_NAAM  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 134612  REGIO LIMBURG
# 134613  REGIO LIMBURG
# 134614  REGIO LIMBURG
# 134615  REGIO LIMBURG
# 134616  REGIO LIMBURG
#
#                                         PLT_NAAM DIENSTCODE DIENSTNAAM  \
# 0       Regionale Eenheid Noord-Nederland               NaN        NaN
# 1       Regionale Eenheid Noord-Nederland               NaN        NaN
# 2       Regionale Eenheid Noord-Nederland                NN         NN
# 3       Regionale Eenheid Noord-Nederland               NaN        NaN
# 4                                            NaN         NN         NN
# ...                                          ...        ...        ...
# 134612  Regionale Eenheid Limburg                       NaN        NaN
# 134613  Regionale Eenheid Limburg                        ZN         ZN
# 134614  Regionale Eenheid Limburg                       NaN        NaN
# 134615  Regionale Eenheid Limburg                       NaN        NaN
# 134616  Regionale Eenheid Limburg                       NaN        NaN
#
#        DISTRCODE              DISTRNAAM DAGTYPE IND_ALC WEEKNR
# 0            NaN                    NaN     NaN     NaN    NaN
# 1            NaN                    NaN     NaN     NaN    NaN
# 2            100       NN District Oost     NaN     NaN    NaN
# 3            NaN                    NaN     NaN     NaN    NaN
# 4            100       NN District Oost     NaN     NaN    NaN
# ...          ...                    ...     ...     ...    ...
# 134612       NaN                    NaN     NaN       J    NaN
# 134613       195  ZN District Zuid-Oost     NaN     NaN    NaN
# 134614       NaN                    NaN     NaN     NaN    NaN
# 134615       NaN                    NaN     NaN     NaN    NaN
# 134616       NaN                    NaN     NaN     NaN    NaN
#
# [134617 rows x 66 columns]

# %%
df.columns
# Out:
# Index(['VKL_NUMMER', 'REGNUMMER', 'PVOPGEM', 'DATUM_VKL', 'DAG_CODE',
#        'MND_NUMMER', 'JAAR_VKL', 'TIJDSTIP', 'UUR', 'DDL_ID', 'AP3_CODE',
#        'AP4_CODE', 'AP5_CODE', 'ANTL_SLA', 'ANTL_DOD', 'ANTL_GZH', 'ANTL_SEH',
#        'ANTL_GOV', 'ANTL_PTJ', 'ANTL_TDT', 'MNE_CODE', 'AOL_ID', 'NIVEAUKOP',
#        'WSE_ID', 'WSE_AN', 'BEBKOM', 'MAXSNELHD', 'WVL_ID', 'WVG_ID', 'WVG_AN',
#        'WDK_ID', 'WDK_AN', 'LGD_ID', 'ZAD_ID', 'WGD_CODE_1', 'WGD_CODE_2',
#        'BZD_ID_VM1', 'BZD_ID_VM2', 'BZD_ID_VM3', 'BZD_VM_AN', 'BZD_ID_IF1',
#        'BZD_ID_IF2', 'BZD_ID_IF3', 'BZD_IF_AN', 'BZD_ID_TA1', 'BZD_ID_TA2',
#        'BZD_ID_TA3', 'BZD_TA_AN', 'JTE_ID', 'WVK_ID', 'HECTOMETER', 'FK_VELD5',
#        'HUISNUMMER', 'GME_ID', 'GME_NAAM', 'PVE_CODE', 'PVE_NAAM', 'KDD_NAAM',
#        'PLT_NAAM', 'DIENSTCODE', 'DIENSTNAAM', 'DISTRCODE', 'DISTRNAAM',
#        'DAGTYPE', 'IND_ALC', 'WEEKNR'],
#       dtype='object')

# %%
# DROPPING UNNCESSARY COLUMNS FOR OUR ANALYSIS

drop_columns = ['REGNUMMER','PVOPGEM', 'DATUM_VKL', 'DAG_CODE',
       'MND_NUMMER','JAAR_VKL', 'TIJDSTIP', 'UUR', 'DDL_ID',
       'AP4_CODE', 'AP5_CODE', 'ANTL_SLA', 'ANTL_DOD', 'ANTL_GZH', 'ANTL_SEH',
       'ANTL_GOV', 'ANTL_TDT', 'MNE_CODE','WSE_AN', 'BEBKOM', 'WVG_ID', 'WVG_AN','WDK_AN',
       'ZAD_ID','WGD_CODE_2','BZD_ID_VM1', 'BZD_ID_VM2', 'BZD_ID_VM3', 'BZD_VM_AN', 'BZD_ID_IF1',
       'BZD_ID_IF2', 'BZD_ID_IF3', 'BZD_IF_AN', 'BZD_ID_TA1', 'BZD_ID_TA2',
       'BZD_ID_TA3', 'BZD_TA_AN', 'JTE_ID', 'WVK_ID', 'HECTOMETER', 'FK_VELD5',
       'HUISNUMMER','PLT_NAAM', 'DIENSTCODE', 'DIENSTNAAM', 
       'DAGTYPE', 'WEEKNR']

df = df.drop(drop_columns,axis=1)

# %%
# KEEP THIS ONE TO SEE ORIGINAL COLUMN NAMES FOR DOCUMENTATION BEFORE RENAMING & ALSO FOR REFERENCES

df.columns

#VKL_NUMMER = Accident_ID
#AP3_CODE = Accident_Outcome                 ### Reference List: Aflopen3 i
#ANTL_PTJ = Number_Involvers
#AOL_ID = Type_Accident                      ### Reference List: AardOngevallen (Earth Accidents)

#NIVEAUKOP = Road_Level                      ### E=Accident exactly linked to BN, K=K = Accident linked at intersection level,S = Accident linked at street level,G = Accident linked to municipal level
#WSE_ID = Road_Situation                     ### Reference List: wegsituaties (Road Situations)
#WVL_ID = Road_Lightning                     ### Reference List: Wegverlichtingen (Road Lighting)
#WDK_ID = Road_Surface                       ### Reference list: Wegdekken (Road surfaces)
#WGD_CODE_1 = Road_Situation_2               ### D = Droog, R = Regen, M = Mist, S = Sneeuw/Hagel, H = Harde windstoten, O = Onbekend


#GME_ID = City_ID
#GME_NAAM = City_Name
#PVE_CODE = Province_Code
#PVE_NAAM = Province_Name
#KDD_NAAM = Regions
#DISTRCODE = District_Code
#DISTRNAAM = District_Name

#IND_ALC = Alcohol_Indication                ### J : Yes , N: No
#MAXSNELHD = Allowed_Max_Speed 
#LGD_ID = Lightning_Conditions_Accident      ### Reference List: Lichtgesteldheden (Lighting Conditions)
# Out:
# Index(['VKL_NUMMER', 'AP3_CODE', 'ANTL_PTJ', 'AOL_ID', 'NIVEAUKOP', 'WSE_ID',
#        'MAXSNELHD', 'WVL_ID', 'WDK_ID', 'LGD_ID', 'WGD_CODE_1', 'GME_ID',
#        'GME_NAAM', 'PVE_CODE', 'PVE_NAAM', 'KDD_NAAM', 'DISTRCODE',
#        'DISTRNAAM', 'IND_ALC'],
#       dtype='object')

# %% [markdown]
# # Create sub-tables
#
# 1) Accidents (Accident ID Primary Key)
# 2) Roads (
# 3) City
# 4) Others
#
# ## Questions
#
# 1) Accident outcome - road situation_2 (If wet, death ratio higher?) -check when it's wet, when it's dry
# 2) Group by city and sum accident ID's to have an idea about number of accidents in each city
# 3) Accident outcome - road lighthning (If day time, accidents more predictable, less death ratio maybe)
# 4) Accident outcome - alcohol indication (if yes more deaths)
# 5) Type of accident happened most in Amsterdam (Refer AardOngevallen.txt and merge the dataframe for demonstration??)

# %%
#RENAMING WHAT'S LEFT

df.columns=['Accident_ID', 'Accident_Outcome', 'Number_Involvers', 'Type_Accident',
       'Road_Level', 'Road_Situation', 'Allowed_Max_Speed', 'Road_Lightning', 'Road_Surface',
       'Lightning_Conditions_Accident', 'Road_Situation_2','City_ID','City_Name','Province_Code', 'Province_Name', 'Regions',
        'District_Code', 'District_Name', 'Alcohol_Indication']

# %%
df.isnull().sum()
# Out:
# Accident_ID                           0
# Accident_Outcome                      0
# Number_Involvers                      0
# Type_Accident                         0
# Road_Level                            0
# Road_Situation                    51768
# Allowed_Max_Speed                 31410
# Road_Lightning                    51760
# Road_Surface                      50929
# Lightning_Conditions_Accident         3
# Road_Situation_2                  52080
# City_ID                               0
# City_Name                             0
# Province_Code                         0
# Province_Name                         0
# Regions                           20271
# District_Code                     90081
# District_Name                     90081
# Alcohol_Indication               132120
# dtype: int64

# %%
#QUICK CHECK NULL COLUMNS TO HAVE AN IDEA (ALSO DONE BEFORE DROPPING COLUMNS) - 0 is the best!! - TO UNDERSTAND DATABASE :)

# In total we have ~134.000 rows..

number_of_missing_cell = []
for column in df.columns:
    number_of_missing_cell.append(df[column].isnull().sum())
    print(column, "has", number_of_missing_cell[-1], "missing value. \n")
# Out:
# Accident_ID has 0 missing value.
#
# Accident_Outcome has 0 missing value.
#
# Number_Involvers has 0 missing value.
#
# Type_Accident has 0 missing value.
#
# Road_Level has 0 missing value.
#
# Road_Situation has 51768 missing value.
#
# Allowed_Max_Speed has 31410 missing value.
#
# Road_Lightning has 51760 missing value.
#
# Road_Surface has 50929 missing value.
#
# Lightning_Conditions_Accident has 3 missing value.
#
# Road_Situation_2 has 52080 missing value.
#
# City_ID has 0 missing value.
#
# City_Name has 0 missing value.
#
# Province_Code has 0 missing value.
#
# Province_Name has 0 missing value.
#
# Regions has 20271 missing value.
#
# District_Code has 90081 missing value.
#
# District_Name has 90081 missing value.
#
# Alcohol_Indication has 132120 missing value.

# %%
# TO SEE DISTINCT VALUES IN EACH COLUMN - for specific ones - TO UNDERSTAND DATABASE :)

df.columns=['Accident_ID', 'Accident_Outcome', 'Number_Involvers', 'Type_Accident',
       'Road_Level', 'Road_Situation', 'Allowed_Max_Speed', 'Road_Lightning', 'Road_Surface',
       'Lightning_Conditions_Accident', 'Road_Situation_2','City_ID','City_Name','Province_Code',
        'Province_Name', 'Regions','District_Code', 'District_Name', 'Alcohol_Indication']

string_columns = ['Accident_Outcome','Type_Accident','Road_Level','Road_Situation','Road_Lightning',
                  'Road_Surface','Lightning_Conditions_Accident','Road_Situation_2','City_Name','Province_Code',
                  'Province_Name','Regions','District_Code', 'District_Name', 'Alcohol_Indication']

distinct_values_in_each_cell = []
for column in df[string_columns]:
    distinct_values_in_each_cell.append(set(df[column].values))
    print(column, "has", distinct_values_in_each_cell[-1], "\n")
# Out:
# Accident_Outcome has {'UMS', 'DOD', 'LET'}
#
# Type_Accident has {'4', '5', '0', '7', '6', '1', '9', '8', '2', '3'}
#
# Road_Level has {'S', 'K', 'G', 'E'}
#
# Road_Situation has {'4', '5', nan, '1', '2', '3'}
#
# Road_Lightning has {nan, '1', '2', '3'}
#
# Road_Surface has {nan, '1', '2', '3'}
#
# Lightning_Conditions_Accident has {nan, '1', '2', '3'}
#
# Road_Situation_2 has {nan, 'M', 'S', 'D', 'R', 'H'}
#
# City_Name has {'Waalwijk', 'Voerendaal', 'Schiermonnikoog', 'Krimpen aan den IJssel', 'Nijkerk', 'Loppersum', 'Oldambt', 'Goes', 'Arnhem', 'Wageningen', 'Heerde', 'Tytsjerksteradiel', 'Noardeast-Fryslân', 'Valkenswaard', 'Gennep', 'Heemstede', 'Horst aan de Maas', 'Meierijstad', 'Hardenberg', 'Kerkrade', 'Bergen (L.)', 'Zaltbommel', 'Bernheze', 'Heusden', 'Amstelveen', 'Veldhoven', 'Deventer', 'Lopik', 'Vaals', 'Steenwijkerland', 'Ameland', 'Oldenzaal', 'Kapelle', 'Rucphen', 'Borne', 'Schouwen-Duiveland', 'Beesel', 'Landgraaf', 'Utrechtse Heuvelrug', 'Steenbergen', 'Medemblik', 'Tiel', 'Lingewaard', 'Baarle-Nassau', 'Uden', 'Nunspeet', 'Noordenveld', 'Hoogeveen', 'Weesp', 'Sluis', 'Bergen (NH.)', 'Leeuwarden', 'Heerlen', 'IJsselstein', 'Diemen', 'Oegstgeest', 'Dinkelland', 'Enkhuizen', 'Edam-Volendam', 'Waddinxveen', "'s-Gravenhage", 'Oirschot', 'Rijswijk', 'Oisterwijk', 'Bladel', 'Westland', 'Koggenland', 'Wormerland', 'Eijsden-Margraten', 'Tynaarlo', 'Hilversum', 'Wijdemeren', 'Tholen', 'Stadskanaal', 'Ermelo', 'Altena', 'Veenendaal', 'Pekela', 'Rheden', 'Oude IJsselstreek', 'Wierden', 'Blaricum', 'Meppel', 'Tubbergen', 'Dongen', 'Beemster', 'Veere', 'Gorinchem', 'Barendrecht', 'Tilburg', 'Lochem', 'Uitgeest', 'Midden-Delfland', 'Someren', 'Delft', 'Staphorst', 'Culemborg', 'Capelle aan den IJssel', 'Boekel', 'Terneuzen', 'Roermond', 'Neder-Betuwe', 'Delfzijl', 'Dalfsen', 'Hellendoorn', 'Nijmegen', 'Haaksbergen', 'Heeze-Leende', 'Apeldoorn', 'Urk', 'De Fryske Marren', 'Roerdalen', 'Moerdijk', 'Barneveld', 'Landerd', 'Roosendaal', 'Beek', 'Haarlemmermeer', 'Eersel', 'Epe', 'Emmen', 'Nuenen  Gerwen en Nederwetten', 'Zeewolde', 'Son en Breugel', 'Westerveld', 'Assen', 'Bronckhorst', 'Bunschoten', 'Heerenveen', 'Alblasserdam', 'Teylingen', 'Laren', 'Alphen-Chaam', 'Bloemendaal', 'Castricum', 'Hillegom', 'Almelo', 'Weert', 'Sint-Michielsgestel', 'Beuningen', 'Stichtse Vecht', 'Loon op Zand', 'Gemert-Bakel', 'Aa en Hunze', 'Ridderkerk', 'Bergen op Zoom', 'Heemskerk', 'Zeist', 'Den Helder', 'Vlieland', 'Best', 'Middelburg', 'Meerssen', 'Noordwijk', 'Sliedrecht', 'Noordoostpolder', 'Achtkarspelen', 'Montfoort', 'Gouda', 'Gooise Meren', 'Kaag en Braassem', 'West Maas en Waal', 'Enschede', 'Buren', 'Vlaardingen', 'Haarlem', 'Hellevoetsluis', 'Pijnacker-Nootdorp', 'Hendrik-Ido-Ambacht', 'Houten', 'Stede Broec', 'Maassluis', 'Waalre', 'Opsterland', 'Vijfheerenlanden', 'Doetinchem', 'Texel', 'Berg en Dal', 'Oosterhout', 'Noord-Beveland', 'Schagen', 'Reusel-De Mierden', 'Zutphen', 'Nissewaard', 'Leidschendam-Voorburg', 'Borger-Odoorn', 'Bunnik', 'Aalsmeer', 'Leiden', 'Rozendaal', 'Alkmaar', 'Brielle', 'Valkenburg aan de Geul', 'Lisse', 'Brunssum', 'Het Hogeland', 'Harlingen', 'Leudal', 'Landsmeer', 'Huizen', 'Reimerswaal', 'Schiedam', 'Overbetuwe', 'Dronten', 'Smallingerland', 'Wijk bij Duurstede', 'Eindhoven', 'Berkelland', 'Opmeer', 'Rhenen', 'Breda', "'s-Hertogenbosch", 'Hattem', 'Cuijk', 'Goirle', 'Baarn', 'Vlissingen', 'Raalte', 'Hulst', 'Scherpenzeel', 'Zoetermeer', 'Zwolle', 'Hardinxveld-Giessendam', 'Midden-Drenthe', 'Oost Gelre', 'Druten', 'Lelystad', 'Doesburg', 'Maastricht', 'Amersfoort', 'Asten', 'Echt-Susteren', 'Oudewater', 'Ooststellingwerf', 'Olst-Wijhe', 'Purmerend', 'Waadhoeke', 'Alphen aan den Rijn', 'Elburg', 'Midden-Groningen', 'Maasdriel', 'Drechterland', 'Deurne', 'Langedijk', 'Gilze en Rijen', 'Nederweert', 'Katwijk', 'Peel en Maas', 'Nieuwegein', 'Heerhugowaard', 'De Wolden', 'Papendrecht', 'Grave', 'Zoeterwoude', 'Drimmelen', 'Dordrecht', 'Sint Anthonis', 'Westerwolde', 'Hollands Kroon', 'Ommen', 'Voorst', 'Waterland', 'Veendam', 'Eemnes', 'Haaren', 'Losser', 'Mook en Middelaar', 'Súdwest-Fryslân', 'Zandvoort', 'Geertruidenberg', 'Mill en Sint Hubert', 'Groningen', 'Cranendonck', 'Bergeijk', 'Boxtel', 'Zwijndrecht', 'Halderberge', 'Aalten', 'Westerkwartier', 'Stein', 'West Betuwe', 'Duiven', 'Hilvarenbeek', 'Heumen', 'Dantumadiel', 'Harderwijk', 'Goeree-Overflakkee', 'Zundert', 'Albrandswaard', 'Ede', 'Westervoor ...
#
# Province_Code has {'GR', 'FR', 'ZH', 'NB', 'UT', 'NH', 'OV', 'LB', 'GL', 'DR', 'FL', 'ZL'}
#
# Province_Name has {'Overijssel', 'Utrecht', 'Friesland', 'Flevoland', 'Drenthe', 'Limburg', 'Noord-Brabant', 'Noord-Holland', 'Zeeland', 'Gelderland', 'Groningen', 'Zuid-Holland'}
#
# Regions has {nan, 'BESTUUR REGIO UTRECHT                   ', 'REGIO ZUID HOLLAND-OV                   ', 'REGIO TWENTE                            ', 'REGIO UTRECHT-OV                        ', 'REGIO NOORD HOLLAND-OV                  ', 'STADSREGIO ROTTERDAM                    ', 'REGIO LIMBURG                           ', 'REGIO NOORD BRABANT-OV                  ', 'REGIO OVERIJSSEL-OV                     ', 'STADSGEWEST HAAGLANDEN                  ', 'REGIO GELDERLAND-OV                     ', 'KNOOPPUNT ARNHEM-NIJMEGEN               ', 'REGIONAAL ORGAAN AMSTERDAM              ', 'SAMENWERKINGSVERBAND REGIO EINDHOVEN    '}
#
# District_Code has {nan, '112', '113', '159', '645', '144', '143', '160', '186', '193', '161', '136', '194', '187', '199', '100', '137', '195'}
#
# District_Name has {nan, 'WNN District Zuid', 'ON District Noord', 'ZD District Noord', 'NN District West', 'ON District Oost', 'ZD District Zuid', 'MN District Noord', 'ZN District Zuid-Oost', 'MN District Zuid', 'WNZ District Zuid', 'WNZ District Noord', 'ZN District West', 'WNN District Noord', 'NN District Oost', 'ZN District Midden', 'ON District Zuid', 'Oost-Nederland District Zuid'}
#
# Alcohol_Indication has {nan, 'J'}
